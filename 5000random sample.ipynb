# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load 
jan_path1 = "1_January/202301-citibike-tripdata_1.csv"  
jan_path2 = "1_January/202301-citibike-tripdata_2.csv"

feb_path1 = "2_February/202302-citibike-tripdata_1.csv"
feb_path2 = "2_February/202302-citibike-tripdata_2.csv"

mar_path1 = "3_March/202303-citibike-tripdata_1.csv"
mar_path2 = "3_March/202303-citibike-tripdata_2.csv"
mar_path3 = "3_March/202303-citibike-tripdata_3.csv"

apr_path1 = "4_April/202304-citibike-tripdata_1.csv"
apr_path2 = "4_April/202304-citibike-tripdata_2.csv"
apr_path3 = "4_April/202304-citibike-tripdata_3.csv"

may_path1 = "5_May/202305-citibike-tripdata_1.csv"
may_path2 = "5_May/202305-citibike-tripdata_2.csv"
may_path3 = "5_May/202305-citibike-tripdata_3.csv"
may_path4 = "5_May/202305-citibike-tripdata_4.csv"

jun_path1 = "6_June/202306-citibike-tripdata_1.csv"
jun_path2 = "6_June/202306-citibike-tripdata_2.csv"
jun_path3 = "6_June/202306-citibike-tripdata_3.csv"
jun_path4 = "6_June/202306-citibike-tripdata_4.csv"

jul_path1 = "7_July/202307-citibike-tripdata_1.csv"
jul_path2 = "7_July/202307-citibike-tripdata_2.csv"
jul_path3 = "7_July/202307-citibike-tripdata_3.csv"
jul_path4 = "7_July/202307-citibike-tripdata_4.csv"

aug_path1 = "8_August/202308-citibike-tripdata_1.csv"
aug_path2 = "8_August/202308-citibike-tripdata_2.csv"
aug_path3 = "8_August/202308-citibike-tripdata_3.csv"
aug_path4 = "8_August/202308-citibike-tripdata_4.csv"
aug_path5 = "8_August/202308-citibike-tripdata_5.csv"

sep_path1 = "9_September/202309-citibike-tripdata_1.csv"
sep_path2 = "9_September/202309-citibike-tripdata_2.csv"
sep_path3 = "9_September/202309-citibike-tripdata_3.csv"
sep_path4 = "9_September/202309-citibike-tripdata_4.csv"

oct_path1 = "10_October/202310-citibike-tripdata_1.csv"
oct_path2 = "10_October/202310-citibike-tripdata_2.csv"
oct_path3 = "10_October/202310-citibike-tripdata_3.csv"
oct_path4 = "10_October/202310-citibike-tripdata_4.csv"

nov_path1 = "11_November/202311-citibike-tripdata_1.csv"
nov_path2 = "11_November/202311-citibike-tripdata_2.csv"
nov_path3 = "11_November/202311-citibike-tripdata_3.csv"

dec_path1 = "12_December/202312-citibike-tripdata_1.csv"
dec_path2 = "12_December/202312-citibike-tripdata_2.csv"
dec_path3 = "12_December/202312-citibike-tripdata_3.csv"

# %%
# Read Jan Data File and store into Pandas DataFrames
jan_data1 = pd.read_csv(jan_path1, low_memory=False)
jan_data2 = pd.read_csv(jan_path2, low_memory=False)

feb_data1 = pd.read_csv(feb_path1, low_memory=False)
feb_data2 = pd.read_csv(feb_path2, low_memory=False)

mar_data1 = pd.read_csv(mar_path1, low_memory=False)
mar_data2 = pd.read_csv(mar_path2, low_memory=False)
mar_data3 = pd.read_csv(mar_path3, low_memory=False)

apr_data1 = pd.read_csv(apr_path1, low_memory=False)
apr_data2 = pd.read_csv(apr_path2, low_memory=False)
apr_data3 = pd.read_csv(apr_path3, low_memory=False)

may_data1 = pd.read_csv(may_path1, low_memory=False)
may_data2 = pd.read_csv(may_path2, low_memory=False)
may_data3 = pd.read_csv(may_path3, low_memory=False)
may_data4 = pd.read_csv(may_path4, low_memory=False)

jun_data1 = pd.read_csv(jun_path1, low_memory=False)
jun_data2 = pd.read_csv(jun_path2, low_memory=False)
jun_data3 = pd.read_csv(jun_path3, low_memory=False)
jun_data4 = pd.read_csv(jun_path4, low_memory=False)

jul_data1 = pd.read_csv(jul_path1, low_memory=False)
jul_data2 = pd.read_csv(jul_path2, low_memory=False)
jul_data3 = pd.read_csv(jul_path3, low_memory=False)
jul_data4 = pd.read_csv(jul_path4, low_memory=False)

aug_data1 = pd.read_csv(aug_path1, low_memory=False)
aug_data2 = pd.read_csv(aug_path2, low_memory=False)
aug_data3 = pd.read_csv(aug_path3, low_memory=False)
aug_data4 = pd.read_csv(aug_path4, low_memory=False)
aug_data5 = pd.read_csv(aug_path5, low_memory=False)

sep_data1 = pd.read_csv(sep_path1, low_memory=False)
sep_data2 = pd.read_csv(sep_path2, low_memory=False)
sep_data3 = pd.read_csv(sep_path3, low_memory=False)
sep_data4 = pd.read_csv(sep_path4, low_memory=False)

oct_data1 = pd.read_csv(oct_path1, low_memory=False)
oct_data2 = pd.read_csv(oct_path2, low_memory=False)
oct_data3 = pd.read_csv(oct_path3, low_memory=False)
oct_data4 = pd.read_csv(oct_path4, low_memory=False)

nov_data1 = pd.read_csv(nov_path1, low_memory=False)
nov_data2 = pd.read_csv(nov_path2, low_memory=False)
nov_data3 = pd.read_csv(nov_path3, low_memory=False)

dec_data1 = pd.read_csv(dec_path1, low_memory=False)
dec_data2 = pd.read_csv(dec_path2, low_memory=False)
dec_data3 = pd.read_csv(dec_path3, low_memory=False)

# %%
num_rows_d1, num_columns_d1 = jan_data1.shape
num_rows_d2, num_columns_d2 = jan_data2.shape

# %%
# check if there's duplicates
duplicates = jan_data1[jan_data1.duplicated()]
num_duplicates = duplicates.shape[0]
num_duplicates
# Out:
# 0

# %%
# randomly select 50000 entries from the data set 
sample_jan1 = jan_data1.sample(n=5000, random_state=1)
sample_jan2 = jan_data2.sample(n=5000, random_state=1)

sample_feb1 = feb_data1.sample(n=5000, random_state=1)
sample_feb2 = feb_data2.sample(n=5000, random_state=1)

sample_mar1 = mar_data1.sample(n=5000, random_state=1)
sample_mar2 = mar_data2.sample(n=5000, random_state=1)
sample_mar3 = mar_data3.sample(n=5000, random_state=1)

sample_apr1 = apr_data1.sample(n=5000, random_state=1)
sample_apr2 = apr_data2.sample(n=5000, random_state=1)
sample_apr3 = apr_data3.sample(n=5000, random_state=1)

sample_may1 = may_data1.sample(n=5000, random_state=1)
sample_may2 = may_data2.sample(n=5000, random_state=1)
sample_may3 = may_data3.sample(n=5000, random_state=1)
sample_may4 = may_data4.sample(n=5000, random_state=1)

sample_jun1 = jun_data1.sample(n=5000, random_state=1)
sample_jun2 = jun_data2.sample(n=5000, random_state=1)
sample_jun3 = jun_data3.sample(n=5000, random_state=1)
sample_jun4 = jun_data4.sample(n=5000, random_state=1)

sample_jul1 = jul_data1.sample(n=5000, random_state=1)
sample_jul2 = jul_data2.sample(n=5000, random_state=1)
sample_jul3 = jul_data3.sample(n=5000, random_state=1)
sample_jul4 = jul_data4.sample(n=5000, random_state=1)

sample_aug1 = aug_data1.sample(n=5000, random_state=1)
sample_aug2 = aug_data2.sample(n=5000, random_state=1)
sample_aug3 = aug_data3.sample(n=5000, random_state=1)
sample_aug4 = aug_data4.sample(n=5000, random_state=1)
sample_aug5 = aug_data5.sample(n=5000, random_state=1)

sample_sep1 = sep_data1.sample(n=5000, random_state=1)
sample_sep2 = sep_data2.sample(n=5000, random_state=1)
sample_sep3 = sep_data3.sample(n=5000, random_state=1)
sample_sep4 = sep_data4.sample(n=5000, random_state=1)

sample_oct1 = oct_data1.sample(n=5000, random_state=1)
sample_oct2 = oct_data2.sample(n=5000, random_state=1)
sample_oct3 = oct_data3.sample(n=5000, random_state=1)
sample_oct4 = oct_data4.sample(n=5000, random_state=1)

sample_nov1 = nov_data1.sample(n=5000, random_state=1)
sample_nov2 = nov_data2.sample(n=5000, random_state=1)
sample_nov3 = nov_data3.sample(n=5000, random_state=1)

sample_dec1 = dec_data1.sample(n=5000, random_state=1)
sample_dec2 = dec_data2.sample(n=5000, random_state=1)
sample_dec3 = dec_data3.sample(n=5000, random_state=1)

# %%
# Save the 5000 sample to a new CSV file
output_file_jan1 = Path("cleaned data/sample_jan_data1.csv")
output_file_jan2 = Path("cleaned data/sample_jan_data2.csv")

output_file_feb1 = Path("cleaned data/sample_feb_data1.csv")
output_file_feb2 = Path("cleaned data/sample_feb_data2.csv")

output_file_mar1 = Path("cleaned data/sample_mar_data1.csv")
output_file_mar2 = Path("cleaned data/sample_mar_data2.csv")
output_file_mar3 = Path("cleaned data/sample_mar_data3.csv")

output_file_apr1 = Path("cleaned data/sample_apr_data1.csv")
output_file_apr2 = Path("cleaned data/sample_apr_data2.csv")
output_file_apr3 = Path("cleaned data/sample_apr_data3.csv")

output_file_may1 = Path("cleaned data/sample_may_data1.csv")
output_file_may2 = Path("cleaned data/sample_may_data2.csv")
output_file_may3 = Path("cleaned data/sample_may_data3.csv")
output_file_may4 = Path("cleaned data/sample_may_data4.csv")

output_file_jun1 = Path("cleaned data/sample_jun_data1.csv")
output_file_jun2 = Path("cleaned data/sample_jun_data2.csv")
output_file_jun3 = Path("cleaned data/sample_jun_data3.csv")
output_file_jun4 = Path("cleaned data/sample_jun_data4.csv")

output_file_jul1 = Path("cleaned data/sample_jul_data1.csv")
output_file_jul2 = Path("cleaned data/sample_jul_data2.csv")
output_file_jul3 = Path("cleaned data/sample_jul_data3.csv")
output_file_jul4 = Path("cleaned data/sample_jul_data4.csv")

output_file_aug1 = Path("cleaned data/sample_aug_data1.csv")
output_file_aug2 = Path("cleaned data/sample_aug_data2.csv")
output_file_aug3 = Path("cleaned data/sample_aug_data3.csv")
output_file_aug4 = Path("cleaned data/sample_aug_data4.csv")
output_file_aug5 = Path("cleaned data/sample_aug_data5.csv")

output_file_sep1 = Path("cleaned data/sample_sep_data1.csv")
output_file_sep2 = Path("cleaned data/sample_sep_data2.csv")
output_file_sep3 = Path("cleaned data/sample_sep_data3.csv")
output_file_sep4 = Path("cleaned data/sample_sep_data4.csv")

output_file_oct1 = Path("cleaned data/sample_oct_data1.csv")
output_file_oct2 = Path("cleaned data/sample_oct_data2.csv")
output_file_oct3 = Path("cleaned data/sample_oct_data3.csv")
output_file_oct4 = Path("cleaned data/sample_oct_data4.csv")

output_file_nov1 = Path("cleaned data/sample_nov_data1.csv")
output_file_nov2 = Path("cleaned data/sample_nov_data2.csv")
output_file_nov3 = Path("cleaned data/sample_nov_data3.csv")
output_file_nov4 = Path("cleaned data/sample_nov_data4.csv")

output_file_dec1 = Path("cleaned data/sample_dec_data1.csv")
output_file_dec2 = Path("cleaned data/sample_dec_data2.csv")
output_file_dec3 = Path("cleaned data/sample_dec_data3.csv")
output_file_dec4 = Path("cleaned data/sample_dec_data4.csv")


sample_jan1.to_csv(output_file_jan1, index=False)
sample_jan2.to_csv(output_file_jan2, index=False)

sample_feb1.to_csv(output_file_feb1, index=False)
sample_feb2.to_csv(output_file_feb2, index=False)

sample_mar1.to_csv(output_file_mar1, index=False)
sample_mar2.to_csv(output_file_mar2, index=False)
sample_mar3.to_csv(output_file_mar3, index=False)

sample_apr1.to_csv(output_file_apr1, index=False)
sample_apr2.to_csv(output_file_apr2, index=False)
sample_apr3.to_csv(output_file_apr3, index=False)

sample_may1.to_csv(output_file_may1, index=False)
sample_may2.to_csv(output_file_may2, index=False)
sample_may3.to_csv(output_file_may3, index=False)
sample_may4.to_csv(output_file_may4, index=False)

sample_jun1.to_csv(output_file_jun1, index=False)
sample_jun2.to_csv(output_file_jun2, index=False)
sample_jun3.to_csv(output_file_jun3, index=False)
sample_jun4.to_csv(output_file_jun4, index=False)

sample_jul1.to_csv(output_file_jul1, index=False)
sample_jul2.to_csv(output_file_jul2, index=False)
sample_jul3.to_csv(output_file_jul3, index=False)
sample_jul4.to_csv(output_file_jul4, index=False)

sample_aug1.to_csv(output_file_aug1, index=False)
sample_aug2.to_csv(output_file_aug2, index=False)
sample_aug3.to_csv(output_file_aug3, index=False)
sample_aug4.to_csv(output_file_aug4, index=False)
sample_aug5.to_csv(output_file_aug5, index=False)

sample_sep1.to_csv(output_file_sep1, index=False)
sample_sep2.to_csv(output_file_sep2, index=False)
sample_sep3.to_csv(output_file_sep3, index=False)
sample_sep4.to_csv(output_file_sep4, index=False)

sample_oct1.to_csv(output_file_oct1, index=False)
sample_oct2.to_csv(output_file_oct2, index=False)
sample_oct3.to_csv(output_file_oct3, index=False)
sample_oct4.to_csv(output_file_oct4, index=False)

sample_nov1.to_csv(output_file_nov1, index=False)
sample_nov2.to_csv(output_file_nov2, index=False)
sample_nov3.to_csv(output_file_nov3, index=False)

sample_dec1.to_csv(output_file_dec1, index=False)
sample_dec2.to_csv(output_file_dec2, index=False)
sample_dec3.to_csv(output_file_dec3, index=False)
